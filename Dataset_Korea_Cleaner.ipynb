# %% [markdown]
# <h1>🧽 Data Cleaning - Dataset C (3042-3879) 🧽</h1>

# %% [markdown]
# Perform data cleaning on a segment in Dataset C.

# %% [markdown]
# <h2>🗃 Import Libraries</h2>

# %%
#pip install geopandas matplotlib folium shapely

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd
import folium
import webbrowser

# %% [markdown]
# <h2>📤 Upload Dataset</h2>

# %%
C_Original_df = pd.read_csv("datasets\input\Dataset_C.csv")

# %% [markdown]
# <h2>🔍 Inspect Dataset</h2>

# %% [markdown]
# <h3>Check Data Types</h3>

# %%
C_Original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4421 entries, 0 to 4420
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Busines Model  4292 non-null   object
#  1   Category       4287 non-null   object
#  2   Subcategory    4284 non-null   object
#  3   Company Name   4392 non-null   object
#  4   Address        4287 non-null   object
#  5   Latitude       4284 non-null   object
#  6   Longitude      4284 non-null   object
#  7   State          4265 non-null   object
#  8   Country        4342 non-null   object
#  9   Contact No.    3986 non-null   object
#  10  Fax No.        2848 non-null   object
#  11  Website        4392 non-null   object
#  12  Email          15 non-null     object
#  13  Annual Sale    4286 non-null   object
#  14  Annual Sales   0 non-null      float64
#  15  Employees      4275 non-null   object
# dtypes: float64(1), object(15)
# memory usage: 552.8+ KB

# %% [markdown]
# <h3>Check For Null Values</h3>

# %%
C_Original_df.isnull().any()
# Out:
# Busines Model    True
# Category         True
# Subcategory      True
# Company Name     True
# Address          True
# Latitude         True
# Longitude        True
# State            True
# Country          True
# Contact No.      True
# Fax No.          True
# Website          True
# Email            True
# Annual Sale      True
# Annual Sales     True
# Employees        True
# dtype: bool

# %% [markdown]
# <h3>Summarize Dataset</h3>

# %%
C_Original_df.describe()
# Out:
#        Annual Sales
# count           0.0
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN

# %% [markdown]
# <h3>Check Random Samples</h3>

# %%
C_Original_df.sample(5)
# Out:
#      Busines Model                Category              Subcategory  \
# 1179           OEM     Packaging Machinery      Packaging Machinery
# 1877           OEM       Lifting Equipment  Aerial Working Platform
# 1193           OEM     Packaging Machinery      Packaging Machinery
# 1033           OEM     Metal Cutting Tools      Metal Cutting Tools
# 476            OEM  Construction Machinery   Construction Machinery
#
#                                       Company Name  \
# 1179        YAMAZEN CORPORATION - Yokkaichi Branch
# 1877  Tadano Co., Ltd. - North Tohoku Sales Office
# 1193        YAMAZEN CORPORATION - Hamamatsu Branch
# 1033           YAMAZEN CORPORATION - Toyama Branch
# 476       Sumitomo Heavy Industries - Nagoya Works
#
#                                                 Address Latitude Longitude  \
# 1179  510-0941 2-5-12 Higashihino, Yokkaichi City, M...  34.9568  136.5967
# 1877  1-35-46 Nishisenboku, Morioka City, Iwate Pref...  39.6854  141.1438
# 1193  435-0046 159 Maruzukacho, Chuo-ku, Hamamatsu C...  34.7291  137.7624
# 1033  939-8087 3-5-13 Oizumicho, Toyama City, Toyama...  36.6841  137.2241
# 476   6-1 Asahichō, Obu City, Aichi Prefecture, 474-...  35.0040  136.9692
#
#          State Country    Contact No.        Fax No.  \
# 1179       Mie   Japan   059-322-8020   059-322-8021
# 1877     Iwate   Japan  (019)635-0611  (019)635-0616
# 1193  Shizuoka   Japan   053-465-6615   053-465-6598
# 1033    Toyama   Japan   076-425-6477   076-425-6499
# 476      Aichi   Japan    562-48-5111            NaN
#
#                          Website Email       Annual Sale  Annual Sales  \
# 1179  https://www.yamazen.co.jp/   NaN  3,339,841,447.20           NaN
# 1877   https://www.tadano.co.jp/   NaN  1,872,176,900.00           NaN
# 1193  https://www.yamazen.co.jp/   NaN  3,339,841,447.20           NaN
# 1033  https://www.yamazen.co.jp/   NaN  3,339,841,447.20           NaN
# 476       https://www.shi.co.jp/   NaN  7,105,849,900.00           NaN
#
#      Employees
# 1179     3,276
# 1877     3,531
# 1193     3,276
# 1033     3,276
# 476     25,303

# %% [markdown]
# <h2>🧼 Clean Dataset</h2>

# %% [markdown]
# <h3>✂️ Remove Irrelevant Data</h3>

# %% [markdown]
# <h4>Slice Dataframe</h4>

# %%
C_df = C_Original_df.iloc[3042:3880]

# %% [markdown]
# <h4>Confirm Shape</h4>

# %%
C_df.shape
# Out:
# (838, 16)

# %% [markdown]
# <h4>Peek Dataframe</h4>

# %%
C_df.head(3)
# Out:
#      Busines Model                                     Category  \
# 3042           OEM                           Electric Machinery
# 3043           OEM  Apparatus & Machinery for Chemical Industry
# 3044           OEM                                Piping System
#
#                               Subcategory  \
# 3042                  Calibration Systems
# 3043  Mechanical seal auxiliary equipment
# 3044  Mechanical seal auxiliary equipment
#
#                                            Company Name  \
# 3042  Eagle Industry Co., Ltd. - Marine Division Kur...
# 3043  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3044  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
#
#                                                 Address Latitude Longitude  \
# 3042  737-0027 No. 8 1 Showa-cho, Kure City, Hiroshi...  34.2506  132.5651
# 3043         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi  34.0421  131.8069
# 3044         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi  34.0421  131.8069
#
#           State Country     Contact No.         Fax No.  \
# 3042  Hiroshima   Japan  (0823) 25-7121  (0823) 25-7120
# 3043  Yamaguchi   Japan  (0834) 63-7648  (0834) 61-1054
# 3044  Yamaguchi   Japan  (0834) 63-7648  (0834) 61-1054
#
#                           Website Email       Annual Sale  Annual Sales  \
# 3042  https://www.ekkeagle.com/jp   NaN  1,117,001,501.90           NaN
# 3043  https://www.ekkeagle.com/jp   NaN  1,117,001,501.90           NaN
# 3044  https://www.ekkeagle.com/jp   NaN  1,117,001,501.90           NaN
#
#      Employees
# 3042     6,280
# 3043     6,280
# 3044     6,280

# %%
C_df.tail(3)
# Out:
#      Busines Model              Category           Subcategory  \
# 3877           OEM  Industrial Machinery  Industrial Machinery
# 3878           OEM  Industrial Machinery  Industrial Machinery
# 3879           OEM  Industrial Machinery  Industrial Machinery
#
#                                 Company Name  \
# 3877     Seika Corp. - Fukuoka Branch Office
# 3878  Seika Corp. - Kitakyushu Branch Office
# 3879        Seika Corp. - Oita Branch Office
#
#                                                 Address Latitude Longitude  \
# 3877  810-0004 Fukuoka City Chuo Ward Watanabedori 2...  33.5828  130.4052
# 3878  802-0001 KMM Building 2-14-1 Asano, Kokurakita...  33.8887  130.8835
# 3879  9th floor, Nissei Oita Ekimae Building, 1-1-18...  33.2347  131.6061
#
#          State Country   Contact No.       Fax No.                 Website  \
# 3877  Fukuoka    Japan  092-731-0471  092-731-0955  https://www.seika.com/
# 3878  Fukuoka    Japan  093-541-1127  093-541-1277  https://www.seika.com/
# 3879     Oita    Japan  097-534-1798  097-533-7494  https://www.seika.com/
#
#      Email     Annual Sale  Annual Sales Employees
# 3877   NaN  576,204,668.25           NaN     1,040
# 3878   NaN  576,204,668.25           NaN     1,040
# 3879   NaN  576,204,668.25           NaN     1,040

# %% [markdown]
# <h4>Remove Annual Sales Field</h4>

# %%
C_df = C_df.drop('Annual Sales', axis=1)

# %%
C_df.head(1)
# Out:
#      Busines Model            Category          Subcategory  \
# 3042           OEM  Electric Machinery  Calibration Systems
#
#                                            Company Name  \
# 3042  Eagle Industry Co., Ltd. - Marine Division Kur...
#
#                                                 Address Latitude Longitude  \
# 3042  737-0027 No. 8 1 Showa-cho, Kure City, Hiroshi...  34.2506  132.5651
#
#           State Country     Contact No.         Fax No.  \
# 3042  Hiroshima   Japan  (0823) 25-7121  (0823) 25-7120
#
#                           Website Email       Annual Sale Employees
# 3042  https://www.ekkeagle.com/jp   NaN  1,117,001,501.90     6,280

# %% [markdown]
# <h4>Remove Newline Characters</h4>

# %%
C_df = C_df.map(lambda x: x.replace('\n', '') if isinstance(x, str) else x)

# %%
C_df = C_df.map(lambda x: x.replace('\r', '') if isinstance(x, str) else x)

# %% [markdown]
# <h3>🕳 Handle Missing or Incomplete Data</h3>

# %% [markdown]
# <h4>Check Field Status</h4>

# %%
C_df.isnull().any()
# Out:
# Busines Model     True
# Category         False
# Subcategory      False
# Company Name     False
# Address          False
# Latitude         False
# Longitude        False
# State             True
# Country           True
# Contact No.       True
# Fax No.           True
# Website          False
# Email             True
# Annual Sale      False
# Employees         True
# dtype: bool

# %%
C_df['Busines Model'].unique()
# Out:
# array(['OEM', 'End-user', nan], dtype=object)

# %% [markdown]
# <h4>Resolve Busines Model</h4>

# %%
null_rows = C_df[C_df['Busines Model'].isna()]

# %%
null_rows
# Out:
#      Busines Model                     Category                 Subcategory  \
# 3754           NaN                       Dryers    Drying/dehydration units
# 3756           NaN  Pollution Control Equipment     Waste treatment support
# 3766           NaN     Industrial Turnkey Plant  Large industrial equipment
# 3767           NaN     Industrial Turnkey Plant       Welding and machining
#
#                                          Company Name  \
# 3754     Tsukishima Holdings Co., Ltd. - Osaka Branch
# 3756    Tsukishima Holdings Co., Ltd. - Kansai Branch
# 3766  Tsukishima Holdings Co., Ltd. - Muroran Factory
# 3767  Tsukishima Holdings Co., Ltd. - Muroran Factory
#
#                                                 Address Latitude Longitude  \
# 3754  541-0048　No. 6, Kawaramachi 3-chome, Chuo-ku, ...  34.6862  135.5033
# 3756  541-0048　No. 6, Kawaramachi 3-chome, Chuo-ku, ...  34.6862  135.5033
# 3766    051-0006　35-2 Chazu-cho, Muroran City, Hokkaido  42.3274  140.9892
# 3767    051-0006　35-2 Chazu-cho, Muroran City, Hokkaido  42.3274  140.9892
#
#      State Country    Contact No.        Fax No.                   Website  \
# 3754   NaN   Japan  (06)6229-1331  (06)6229-1415  https://www.tsk-g.co.jp/
# 3756   NaN   Japan  (06)6229-1331  (06)6229-1415  https://www.tsk-g.co.jp/
# 3766   NaN   Japan  (0143)57-1100  (0143)57-1102  https://www.tsk-g.co.jp/
# 3767   NaN   Japan  (0143)57-1100  (0143)57-1102  https://www.tsk-g.co.jp/
#
#       Email     Annual Sale Employees
# 3754    NaN  824,652,887.25     3,517
# 3756    NaN  824,652,887.25     3,517
# 3766    NaN  824,652,887.25     3,517
# 3767    NaN  824,652,887.25     3,517

# %%
C_df['Busines Model'] = C_df['Busines Model'].fillna('OEM')

# %% [markdown]
# <h4>Resolve State</h4>

# %%
null_rows = C_df[C_df['State'].isna()]

# %%
null_rows
# Out:
#      Busines Model                                           Category  \
# 3751           OEM                        Pollution Control Equipment
# 3752           OEM  Planning, Consulting & Construction of Complet...
# 3753           OEM                                             Dryers
# 3754           OEM                                             Dryers
# 3755           OEM                        Pollution Control Equipment
# 3756           OEM                        Pollution Control Equipment
# 3757           OEM  Planning, Consulting & Construction of Complet...
# 3758           OEM                        Pollution Control Equipment
# 3759           OEM                        Pollution Control Equipment
# 3760           OEM                        Pollution Control Equipment
# 3761           OEM                        Pollution Control Equipment
# 3762           OEM                        Pollution Control Equipment
# 3763           OEM                        Pollution Control Equipment
# 3764           OEM                   Machinery Equipment for Services
# 3765           OEM                           Industrial Turnkey Plant
# 3766           OEM                           Industrial Turnkey Plant
# 3767           OEM                           Industrial Turnkey Plant
# 3821           OEM                Productronics Machinery & Equipment
# 3822           OEM  Precision Machinery, Inspecting & Testing Equi...
#
#                                             Subcategory  \
# 3751                            Water treatment systems
# 3752                      Engineering support for water
# 3753                       Wastewater treatment systems
# 3754                           Drying/dehydration units
# 3755                                   Municipal sewage
# 3756                            Waste treatment support
# 3757                         Regional support for water
# 3758                         Water treatment consulting
# 3759                    Environmental plant engineering
# 3760     Sales and project support for treatment plants
# 3761  Environmental plant equipment sales and consul...
# 3762      West Japan environmental engineering projects
# 3763      Local sales support for environmental systems
# 3764                                  Mechanical design
# 3765                                Production of tanks
# 3766                         Large industrial equipment
# 3767                              Welding and machining
# 3821                                   Printing Systems
# 3822                                Precision machining
#
#                                            Company Name  \
# 3751  Tsukishima Holdings Co., Ltd. - East Japan Branch
# 3752       Tsukishima Holdings Co., Ltd. - Kanto Branch
# 3753       Tsukishima Holdings Co., Ltd. - Osaka Branch
# 3754       Tsukishima Holdings Co., Ltd. - Osaka Branch
# 3755      Tsukishima Holdings Co., Ltd. - Kansai Branch
# 3756      Tsukishima Holdings Co., Ltd. - Kansai Branch
# 3757     Tsukishima Holdings Co., Ltd. - Sapporo Branch
# 3758      Tsukishima Holdings Co., Ltd. - Sendai Branch
# 3759    Tsukishima Holdings Co., Ltd. - Yokohama Branch
# 3760      Tsukishima Holdings Co., Ltd. - Nagoya Branch
# 3761       Tsukishima Holdings Co., Ltd. - China Branch
# 3762     Tsukishima Holdings Co., Ltd. - Fukuoka Branch
# 3763     Tsukishima Holdings Co., Ltd. - Okinawa Office
# 3764     Tsukishima Holdings Co., Ltd. - Yachiyo Office
# 3765    Tsukishima Holdings Co., Ltd. - Muroran Factory
# 3766    Tsukishima Holdings Co., Ltd. - Muroran Factory
# 3767    Tsukishima Holdings Co., Ltd. - Muroran Factory
# 3821  Sinfonia Technology Co., Ltd. - Ise Seisakusho...
# 3822       Sinfonia Technology Co., Ltd. - Toba Factory
#
#                                                 Address Latitude Longitude  \
# 3751     104-0053　No. 5, Harumi 3-chome, Chuo-ku, Tokyo  35.7078  139.7795
# 3752     104-0053　No. 5, Harumi 3-chome, Chuo-ku, Tokyo  35.7078  139.7795
# 3753  541-0048　No. 6, Kawaramachi 3-chome, Chuo-ku, ...  34.6862  135.5033
# 3754  541-0048　No. 6, Kawaramachi 3-chome, Chuo-ku, ...  34.6862  135.5033
# 3755  541-0048　No. 6, Kawaramachi 3-chome, Chuo-ku, ...  34.6862  135.5033
# 3756  541-0048　No. 6, Kawaramachi 3-chome, Chuo-ku, ...  34.6862  135.5033
# 3757  060-0807　1-2 Kitashichijo Nishi 4-chome, Kita-...  35.6556  139.7797
# 3758  980-0014　11-2 Honmachi, Aoba-ku, Sendai (SK Se...  35.6563  139.7800
# 3759  231-0012　1, 56 Aioicho 3-chome, Naka-ku, Yokoh...  35.6563  139.7800
# 3760  450-0003　No. 17, 29, Meieki Minami 1-chome, Na...  35.6563  139.7800
# 3761  730-0015　No. 10, Hashimotocho, Naka-ku, Hirosh...  35.6648  139.7828
# 3762  810-0062　Arato 2-chome No. 1 No. 5, Chuo-ku, F...  35.6560  139.7796
# 3763  901-2131　Makiminato 2-chome 54-No. 2, Urasoe C...  26.2626  127.7261
# 3764  276-0022　3, 1807 Kamikono, Yachiyo City, Chiba...  35.7335  140.1331
# 3765    051-0006　35-2 Chazu-cho, Muroran City, Hokkaido  42.3274  140.9892
# 3766    051-0006　35-2 Chazu-cho, Muroran City, Hokkaido  42.3274  140.9892
# 3767    051-0006　35-2 Chazu-cho, Muroran City, Hokkaido  42.3274  140.9892
# 3821  516-8550 100 Takegahana-cho, Ise City, Mie Pre...  34.5093  136.7282
# 3822    517-0011 1-19-1 Toba, Toba City, Mie Prefecture  34.4850  136.8279
#
#      State Country    Contact No.        Fax No.  \
# 3751   NaN   Japan  (03)5560-6541  (03)5560-6593
# 3752   NaN   Japan  (03)5560-6542  (03)5560-6593
# 3753   NaN   Japan  (06)6229-1331  (06)6229-1415
# 3754   NaN   Japan  (06)6229-1331  (06)6229-1415
# 3755   NaN   Japan  (06)6229-1331  (06)6229-1415
# 3756   NaN   Japan  (06)6229-1331  (06)6229-1415
# 3757   NaN   Japan  (011)726-0510  (011)726-0520
# 3758   NaN   Japan  (022)227-9267  (022)223-0316
# 3759   NaN   Japan  (045)651-7331  (045)664-5086
# 3760   NaN   Japan  (052)581-2378  (052)581-1624
# 3761   NaN   Japan  (082)227-3093  (082)223-8771
# 3762   NaN   Japan  (092)741-5736  (092)761-4806
# 3763   NaN   Japan  (098)874-5793  (098)874-6262
# 3764   NaN   Japan  (047)494-4300  (047)494-4321
# 3765   NaN   Japan  (0143)57-1100  (0143)57-1102
# 3766   NaN   Japan  (0143)57-1100  (0143)57-1102
# 3767   NaN   Japan  (0143)57-1100  (0143)57-1102
# 3821   NaN   Japan   0596-36-1111   0596-36-0577
# 3822   NaN   Japan   0599-25-3231   0599-25-5162
#
#                                             Website  Email     Annual Sale  \
# 3751                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3752                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3753                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3754                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3755                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3756                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3757                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3758                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3759                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3760                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3761                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3762                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3763                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3764                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3765                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3766                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3767                       https://www.tsk-g.co.jp/    NaN  824,652,887.25
# 3821  https://www.sinfo-t.jp/company/business-base/    NaN  681,586,018.65
# 3822  https://www.sinfo-t.jp/company/business-base/    NaN  681,586,018.65
#
#      Employees
# 3751     3,517
# 3752     3,517
# 3753     3,517
# 3754     3,517
# 3755     3,517
# 3756     3,517
# 3757     3,517
# 3758     3,517
# 3759     3,517
# 3760     3,517
# 3761     3,517
# 3762     3,517
# 3763     3,517
# 3764     3,517
# 3765     3,517
# 3766     3,517
# 3767     3,517
# 3821     3,683
# 3822     3,683

# %%
C_df.loc[3751:3752, 'State'] = 'Tokyo'
C_df.loc[3753:3757, 'State'] = 'Osaka'
C_df.loc[3758, 'State'] = 'Miyagi'
C_df.loc[3759, 'State'] = 'Kanagawa'
C_df.loc[3760, 'State'] = 'Kochi'
C_df.loc[3761, 'State'] = 'Hiroshima'
C_df.loc[3762, 'State'] = 'Fukuoka'
C_df.loc[3763, 'State'] = 'Okinawa'
C_df.loc[3764, 'State'] = 'Chiba'
C_df.loc[3765:3767, 'State'] = 'Hokkaido'
C_df.loc[3821:3822, 'State'] = 'Mie'

# %%
C_df.loc[3822]
# Out:
# Busines Model                                                  OEM
# Category         Precision Machinery, Inspecting & Testing Equi...
# Subcategory                                    Precision machining
# Company Name          Sinfonia Technology Co., Ltd. - Toba Factory
# Address            517-0011 1-19-1 Toba, Toba City, Mie Prefecture
# Latitude                                                   34.4850
# Longitude                                                 136.8279
# State                                                          Mie
# Country                                                      Japan
# Contact No.                                           0599-25-3231
# Fax No.                                               0599-25-5162
# Website              https://www.sinfo-t.jp/company/business-base/
# Email                                                          NaN
# Annual Sale                                         681,586,018.65
# Employees                                                    3,683
# Name: 3822, dtype: object

# %% [markdown]
# <h4>Resolve Country</h4>

# %%
C_df['Country'].unique()
# Out:
# array(['Japan', nan], dtype=object)

# %%
C_df['Country'] = C_df['Country'].fillna('Japan')

# %% [markdown]
# <h4>Resolve Contact No.</h4>

# %%
C_df['Contact No.'] = C_df['Contact No.'].fillna('')

# %% [markdown]
# <h4>Resolve Fax No.</h4>

# %%
C_df['Fax No.'] = C_df['Fax No.'].fillna('')

# %% [markdown]
# <h4>Resolve Email</h4>

# %%
C_df['Email'] = C_df['Email'].fillna('-')

# %% [markdown]
# <h4>Resolve Employees</h4>

# %%
null_rows = C_df[C_df['Employees'].isna()]

# %%
null_rows
# Out:
#      Busines Model                                           Category  \
# 3277           OEM  Precision Machinery, Inspecting & Testing Equi...
# 3278           OEM                Productronics Machinery & Equipment
# 3279           OEM                               Industrial Machinery
# 3280           OEM                                            Casting
# 3281           OEM                Productronics Machinery & Equipment
# 3282           OEM                Productronics Machinery & Equipment
# 3283           OEM                Productronics Machinery & Equipment
# 3284           OEM                Productronics Machinery & Equipment
# 3285           OEM                                Packaging Machinery
# 3286           OEM                               Subcontract Services
# 3287           OEM                Productronics Machinery & Equipment
#
#                                             Subcategory  \
# 3277             Digital Modeling, CG, Optical analysis
# 3278             Product design, Proof of Concept (POC)
# 3279                         3D Printing, CNC Machining
# 3280                  Vacuum casting, Microwave molding
# 3281                    Resin processing, Block molding
# 3282                             Sheet Metal Processing
# 3283  Simple mold, Injection molding, Small-scale pr...
# 3284                       Decoration/Surface treatment
# 3285                                Packaging Solutions
# 3286  A combination of design, engineering, prototyp...
# 3287                             Proof of Concept (POC)
#
#                                 Company Name  \
# 3277          Arrk Corporation - Head Office
# 3278    Arrk Corporation - Tokyo Head Office
# 3279          Arrk Corporation - Head Office
# 3280     Arrk Corporation - Harajuku Factory
# 3281     Arrk Corporation - Harajuku Factory
# 3282  Arrk Corporation - Fujiyoshida Factory
# 3283  Arrk Corporation - Fujiyoshida Factory
# 3284  Arrk Corporation - Fujiyoshida Factory
# 3285  Arrk Corporation - Osaka Branch Office
# 3286  Arrk Corporation - Fujiyoshida Factory
# 3287    Arrk Corporation - Tokyo Head Office
#
#                                                 Address Latitude Longitude  \
# 3277  11th floor, Tatsuno Minamihonmachi Building, 2...  34.6789  135.5022
# 3278  1-7-1 Izumi, Asaka City, Saitama Prefecture, 3...  35.8008  139.6019
# 3279  11th floor, Tatsuno Minamihonmachi Building, 2...  34.6789  135.5022
# 3280  770 Harajuku Ipponsugi, Hidaka City, Saitama P...  35.9086  139.3432
# 3281  770 Harajuku Ipponsugi, Hidaka City, Saitama P...  35.9086  139.3432
# 3282  2-12-8 Mukaihara, Fujiyoshida City, Yamanashi ...  35.4872  138.8067
# 3283  2-12-8 Mukaihara, Fujiyoshida City, Yamanashi ...  35.4872  138.8067
# 3284  2-12-8 Mukaihara, Fujiyoshida City, Yamanashi ...  35.4872  138.8067
# 3285  2-4-3 Kawamocho, Tondabayashi City, Osaka Pref...  34.5004  135.5973
# 3286  2-12-8 Mukaihara, Fujiyoshida City, Yamanashi ...  35.4872  138.8067
# 3287  1-7-1 Izumi, Asaka City, Saitama Prefecture, 3...  35.8008  139.6019
#
#           State Country   Contact No.       Fax No.               Website  \
# 3277      Osaka   Japan                              https://jp.arrk.com/
# 3278    Saitama   Japan  048-458-5055  048-458-5532  https://jp.arrk.com/
# 3279      Osaka   Japan                              https://jp.arrk.com/
# 3280    Saitama   Japan                              https://jp.arrk.com/
# 3281    Saitama   Japan                              https://jp.arrk.com/
# 3282  Yamanashi   Japan  0555-24-1811  0555-20-1080  https://jp.arrk.com/
# 3283  Yamanashi   Japan  0555-24-1811  0555-20-1080  https://jp.arrk.com/
# 3284  Yamanashi   Japan  0555-24-1811  0555-20-1080  https://jp.arrk.com/
# 3285      Osaka   Japan  0721-24-0403  0721-24-0455  https://jp.arrk.com/
# 3286  Yamanashi   Japan  0555-24-1811  0555-20-1080  https://jp.arrk.com/
# 3287    Saitama   Japan  048-458-5055  048-458-5532  https://jp.arrk.com/
#
#      Email    Annual Sale Employees
# 3277     -  79,378,900.00       NaN
# 3278     -  79,378,900.00       NaN
# 3279     -  79,378,900.00       NaN
# 3280     -  79,378,900.00       NaN
# 3281     -  79,378,900.00       NaN
# 3282     -  79,378,900.00       NaN
# 3283     -  79,378,900.00       NaN
# 3284     -  79,378,900.00       NaN
# 3285     -  79,378,900.00       NaN
# 3286     -  79,378,900.00       NaN
# 3287     -  79,378,900.00       NaN

# %%
Employees_median = round(C_df['Employees'].str.replace(',', '').astype('Int64').median())
Str_Employees_median = str(Employees_median)

# %%
C_df['Employees'] = C_df['Employees'].fillna(Str_Employees_median)

# %%
C_df['Employees'] = C_df['Employees'].str.replace(',', '')

# %%
C_df['Employees'] = pd.to_numeric(C_df['Employees'], errors='coerce').astype('Int64')

# %% [markdown]
# <h4>Finalize Field Status</h4>

# %%
C_df.isnull().any()
# Out:
# Busines Model    False
# Category         False
# Subcategory      False
# Company Name     False
# Address          False
# Latitude         False
# Longitude        False
# State            False
# Country          False
# Contact No.      False
# Fax No.          False
# Website          False
# Email            False
# Annual Sale      False
# Employees        False
# dtype: bool

# %% [markdown]
# <h3>⚠️ Fix Formatting Issues</h3>

# %% [markdown]
# <h4>Check DType</h4>

# %%
C_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 3042 to 3879
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Busines Model  838 non-null    object
#  1   Category       838 non-null    object
#  2   Subcategory    838 non-null    object
#  3   Company Name   838 non-null    object
#  4   Address        838 non-null    object
#  5   Latitude       838 non-null    object
#  6   Longitude      838 non-null    object
#  7   State          838 non-null    object
#  8   Country        838 non-null    object
#  9   Contact No.    838 non-null    object
#  10  Fax No.        838 non-null    object
#  11  Website        838 non-null    object
#  12  Email          838 non-null    object
#  13  Annual Sale    838 non-null    object
#  14  Employees      838 non-null    Int64
# dtypes: Int64(1), object(14)
# memory usage: 99.2+ KB

# %% [markdown]
# <h4>Format Company Name</h4>

# %%
C_df['Company Name'] = C_df['Company Name'].str.title()

# %% [markdown]
# <h4>Change Latitude 'object' to 'float64'</h4>

# %%
C_df['Latitude'] = pd.to_numeric(C_df['Latitude'], errors='coerce').astype('float64')

# %% [markdown]
# <h4>Change Longitude 'object' to 'float64'</h4>

# %%
C_df['Longitude'] = pd.to_numeric(C_df['Longitude'], errors='coerce').astype('float64')

# %% [markdown]
# <h4>Change Annual Sale 'object' to 'float128'</h4>

# %%
C_df['Annual Sale'] = C_df['Annual Sale'].str.replace(',', '')

# %%
C_df['Annual Sale'] = pd.to_numeric(C_df['Annual Sale'], errors='coerce').astype('Float64')

# %% [markdown]
# <h4>Format Contact No.</h4>

# %%
C_df['Contact No.'] = C_df['Contact No.'].str.replace('-', '').str.replace('(', '').str.replace(')', '').str.replace(' ', '')

# %%
C_df['Contact No.'] = C_df['Contact No.'].str.slice(0, 10)

# %%
C_df['Contact No.'] = C_df['Contact No.'].str.replace(r'^81', '+81', regex=True)
C_df['Contact No.'] = C_df['Contact No.'].str.replace(r'^0', '+81', regex=True)

# %%
C_df['Contact No.'] = C_df['Contact No.'].str.slice_replace(start = 0, stop = 0, repl = '(')
C_df['Contact No.'] = C_df['Contact No.'].str.slice_replace(start = 4, stop = 4, repl = ')')

# %%
C_df['Contact No.'] = C_df['Contact No.'].str.slice_replace(start = 5, stop = 5, repl = ' ')
C_df['Contact No.'] = C_df['Contact No.'].str.slice_replace(start = 7, stop = 7, repl = '-')

# %%
C_df['Contact No.'] = C_df['Contact No.'].str.slice_replace(start = 12, stop = 12, repl = '-')

# %%
C_df.head(5)
# Out:
#      Busines Model                                     Category  \
# 3042           OEM                           Electric Machinery
# 3043           OEM  Apparatus & Machinery for Chemical Industry
# 3044           OEM                                Piping System
# 3045           OEM                     Industrial Turnkey Plant
# 3046           OEM                  Pollution Control Equipment
#
#                               Subcategory  \
# 3042                  Calibration Systems
# 3043  Mechanical seal auxiliary equipment
# 3044  Mechanical seal auxiliary equipment
# 3045  Mechanical seal auxiliary equipment
# 3046  Mechanical seal auxiliary equipment
#
#                                            Company Name  \
# 3042  Eagle Industry Co., Ltd. - Marine Division Kur...
# 3043  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3044  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3045  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3046  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
#
#                                                 Address  Latitude  Longitude  \
# 3042  737-0027 No. 8 1 Showa-cho, Kure City, Hiroshi...   34.2506   132.5651
# 3043         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# 3044         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# 3045         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# 3046         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
#
#           State Country        Contact No.         Fax No.  \
# 3042  Hiroshima   Japan  (+81) 8-2325-7121  (0823) 25-7120
# 3043  Yamaguchi   Japan  (+81) 8-3463-7648  (0834) 61-1054
# 3044  Yamaguchi   Japan  (+81) 8-3463-7648  (0834) 61-1054
# 3045  Yamaguchi   Japan  (+81) 8-3463-7648  (0834) 61-1054
# 3046  Yamaguchi   Japan  (+81) 8-3463-7648  (0834) 61-1054
#
#                           Website Email   Annual Sale  Employees
# 3042  https://www.ekkeagle.com/jp     -  1117001501.9       6280
# 3043  https://www.ekkeagle.com/jp     -  1117001501.9       6280
# 3044  https://www.ekkeagle.com/jp     -  1117001501.9       6280
# 3045  https://www.ekkeagle.com/jp     -  1117001501.9       6280
# 3046  https://www.ekkeagle.com/jp     -  1117001501.9       6280

# %%
C_df['Contact No.'] = C_df['Contact No.'].str.replace('() -', '')

# %%
C_df['Contact No.'] = C_df['Contact No.'].str.split('\r').str[0]

# %%
C_df.loc[3268]
# Out:
# Busines Model                                           OEM
# Category                                 Electric Machinery
# Subcategory                              Electric Machinery
# Company Name                                       Yamabiko
# Address          1-7-2 Suehirocho, Ome City, Tokyo 198-0025
# Latitude                                            35.7802
# Longitude                                           139.309
# State                                                 Tokyo
# Country                                               Japan
# Contact No.                               (+81) 4-2832-1005
# Fax No.
# Website            https://www.yamabiko-corp.co.jp/kioritz/
# Email                                                     -
# Annual Sale                                     259229538.0
# Employees                                               476
# Name: 3268, dtype: object

# %% [markdown]
# <h4>Format Fax No.</h4>

# %%
C_df['Fax No.'] = C_df['Fax No.'].str.replace('-', '').str.replace('(', '').str.replace(')', '').str.replace(' ', '')

# %%
C_df['Fax No.'] = C_df['Fax No.'].str.slice(0, 10)

# %%
C_df['Fax No.'] = C_df['Fax No.'].str.replace(r'^81', '+81', regex=True)
C_df['Fax No.'] = C_df['Fax No.'].str.replace(r'^0', '+81', regex=True)

# %%
C_df['Fax No.'] = C_df['Fax No.'].str.slice_replace(start = 0, stop = 0, repl = '(')
C_df['Fax No.'] = C_df['Fax No.'].str.slice_replace(start = 4, stop = 4, repl = ')')

# %%
C_df['Fax No.'] = C_df['Fax No.'].str.slice_replace(start = 5, stop = 5, repl = ' ')
C_df['Fax No.'] = C_df['Fax No.'].str.slice_replace(start = 7, stop = 7, repl = '-')

# %%
C_df['Fax No.'] = C_df['Fax No.'].str.slice_replace(start = 12, stop = 12, repl = '-')

# %%
C_df.head(5)
# Out:
#      Busines Model                                     Category  \
# 3042           OEM                           Electric Machinery
# 3043           OEM  Apparatus & Machinery for Chemical Industry
# 3044           OEM                                Piping System
# 3045           OEM                     Industrial Turnkey Plant
# 3046           OEM                  Pollution Control Equipment
#
#                               Subcategory  \
# 3042                  Calibration Systems
# 3043  Mechanical seal auxiliary equipment
# 3044  Mechanical seal auxiliary equipment
# 3045  Mechanical seal auxiliary equipment
# 3046  Mechanical seal auxiliary equipment
#
#                                            Company Name  \
# 3042  Eagle Industry Co., Ltd. - Marine Division Kur...
# 3043  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3044  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3045  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3046  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
#
#                                                 Address  Latitude  Longitude  \
# 3042  737-0027 No. 8 1 Showa-cho, Kure City, Hiroshi...   34.2506   132.5651
# 3043         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# 3044         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# 3045         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# 3046         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
#
#           State Country        Contact No.            Fax No.  \
# 3042  Hiroshima   Japan  (+81) 8-2325-7121  (+81) 8-2325-7120
# 3043  Yamaguchi   Japan  (+81) 8-3463-7648  (+81) 8-3461-1054
# 3044  Yamaguchi   Japan  (+81) 8-3463-7648  (+81) 8-3461-1054
# 3045  Yamaguchi   Japan  (+81) 8-3463-7648  (+81) 8-3461-1054
# 3046  Yamaguchi   Japan  (+81) 8-3463-7648  (+81) 8-3461-1054
#
#                           Website Email   Annual Sale  Employees
# 3042  https://www.ekkeagle.com/jp     -  1117001501.9       6280
# 3043  https://www.ekkeagle.com/jp     -  1117001501.9       6280
# 3044  https://www.ekkeagle.com/jp     -  1117001501.9       6280
# 3045  https://www.ekkeagle.com/jp     -  1117001501.9       6280
# 3046  https://www.ekkeagle.com/jp     -  1117001501.9       6280

# %%
C_df['Fax No.'] = C_df['Fax No.'].str.replace('() -', '')

# %% [markdown]
# <h4>Format Website</h4>

# %%
C_df['Website'] = C_df['Website'].str.replace('https://', '')
C_df['Website'] = C_df['Website'].str.replace('http://', '')

# %%
C_df.sample(5)
# Out:
#      Busines Model                                     Category  \
# 3687           OEM                          Packaging Machinery
# 3263           OEM                  Pollution Control Equipment
# 3110           OEM  Machinery for Non-metallic Mineral Products
# 3467           OEM                      Metal Forming Machinery
# 3612           OEM                                      Casting
#
#                                       Subcategory  \
# 3687                              Bottling System
# 3263                           Cleaning Equipment
# 3110  Machinery for Non-metallic Mineral Products
# 3467                                Bending Rolls
# 3612                            Casting Equipment
#
#                                            Company Name  \
# 3687                                       Shibuya Corp
# 3263                     Miura Co., Ltd. - Hojo Factory
# 3110  Shibaura Machine Co., Ltd. - Shibaura Machine ...
# 3467                    Kurimoto, Ltd. - Kagaya Factory
# 3612            Kurimoto, Ltd. - Kanto Logistics Center
#
#                                                 Address  Latitude  Longitude  \
# 3687  58, Omameda Honmachi, Kanazawa City, Ishikawa ...   36.5688   136.6558
# 3263  864-1 Hojo-tsuji, Matsuyama City, Ehime Prefec...   33.9631   132.7800
# 3110  100-8503 Fukoku Seimei Building 4F, 2-2-2 Uchi...   35.6711   139.7550
# 3467           2-1-64 Izumi, Suminoe-ku, Osaka 559-0023   34.6134   135.4646
# 3612  1-2-2 Higashihama, Ichikawa City, Chiba Prefec...   34.6744   135.4905
#
#           State Country        Contact No.            Fax No.  \
# 3687  Ishikawa    Japan  (+81) 7-6262-1201  (+81) 7-6223-1914
# 3263      Ehime   Japan                  -                  -
# 3110      Tokyo   Japan  (+81) 3-3509-0200  (+81) 3-3509-0333
# 3467      Osaka   Japan  (+81) 6-6686-1010                  -
# 3612      Chiba   Japan  (+81) 4-7320-6665                  -
#
#                           Website Email    Annual Sale  Employees
# 3687           www.shibuya.co.jp/     -    766418271.3       3248
# 3263            www.miuraz.co.jp/     -   1685492700.0       6059
# 3110  www.shibaura-machine.co.jp/     -  1074278578.35       3507
# 3467          www.kurimoto.co.jp/     -   836072741.25       2121
# 3612          www.kurimoto.co.jp/     -   836072741.25       2121

# %% [markdown]
# <h4>Finalize DType</h4>

# %%
C_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 838 entries, 3042 to 3879
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Busines Model  838 non-null    object
#  1   Category       838 non-null    object
#  2   Subcategory    838 non-null    object
#  3   Company Name   838 non-null    object
#  4   Address        838 non-null    object
#  5   Latitude       838 non-null    float64
#  6   Longitude      838 non-null    float64
#  7   State          838 non-null    object
#  8   Country        838 non-null    object
#  9   Contact No.    838 non-null    object
#  10  Fax No.        838 non-null    object
#  11  Website        838 non-null    object
#  12  Email          838 non-null    object
#  13  Annual Sale    838 non-null    Float64
#  14  Employees      838 non-null    Int64
# dtypes: Float64(1), Int64(1), float64(2), object(11)
# memory usage: 100.0+ KB

# %%
C_df.isnull().any()
# Out:
# Busines Model    False
# Category         False
# Subcategory      False
# Company Name     False
# Address          False
# Latitude         False
# Longitude        False
# State            False
# Country          False
# Contact No.      False
# Fax No.          False
# Website          False
# Email            False
# Annual Sale      False
# Employees        False
# dtype: bool

# %%
C_df.tail(3)
# Out:
#      Busines Model              Category           Subcategory  \
# 3877           OEM  Industrial Machinery  Industrial Machinery
# 3878           OEM  Industrial Machinery  Industrial Machinery
# 3879           OEM  Industrial Machinery  Industrial Machinery
#
#                                 Company Name  \
# 3877     Seika Corp. - Fukuoka Branch Office
# 3878  Seika Corp. - Kitakyushu Branch Office
# 3879        Seika Corp. - Oita Branch Office
#
#                                                 Address  Latitude  Longitude  \
# 3877  810-0004 Fukuoka City Chuo Ward Watanabedori 2...   33.5828   130.4052
# 3878  802-0001 KMM Building 2-14-1 Asano, Kokurakita...   33.8887   130.8835
# 3879  9th floor, Nissei Oita Ekimae Building, 1-1-18...   33.2347   131.6061
#
#          State Country        Contact No.            Fax No.         Website  \
# 3877  Fukuoka    Japan  (+81) 9-2731-0471  (+81) 9-2731-0955  www.seika.com/
# 3878  Fukuoka    Japan  (+81) 9-3541-1127  (+81) 9-3541-1277  www.seika.com/
# 3879     Oita    Japan  (+81) 9-7534-1798  (+81) 9-7533-7494  www.seika.com/
#
#      Email   Annual Sale  Employees
# 3877     -  576204668.25       1040
# 3878     -  576204668.25       1040
# 3879     -  576204668.25       1040

# %% [markdown]
# <h3>🎏 Remove Duplicate Records</h3>

# %% [markdown]
# <h4>Check Current Shape of Dataframe</h4>

# %%
C_df.shape
# Out:
# (838, 15)

# %% [markdown]
# <h4>Count Duplicate Rows for Validation</h4>

# %%
duplicate_rows = C_df[C_df.duplicated()]
duplicate_rows.shape[0]
# Out:
# 12

# %%
C_df = C_df.drop_duplicates(keep = 'first')

# %% [markdown]
# <h4>Check New Shape of Dataframe</h4>

# %%
C_df.shape
# Out:
# (826, 15)

# %% [markdown]
# <h3>🌐 Validate Geolocation Data</h3>

# %% [markdown]
# <h4>Get Country Borders</h4>

# %%
geo_df = gpd.read_file("https://d2ad6b4ur7yvpq.cloudfront.net/naturalearth-3.3.0/ne_50m_admin_0_countries.geojson")

# %%
country = geo_df[geo_df['name'] == 'Japan']

# %% [markdown]
# <h4>Convert To GeoDataFrame</h4>

# %%
C_df_copy = C_df

# %%
geo_df = gpd.GeoDataFrame(C_df_copy, geometry = gpd.points_from_xy(
    C_df_copy['Longitude'], C_df_copy['Latitude']), crs="EPSG:4326")

# %% [markdown]
# <h4>Check Coordinates</h4>

# %%
points_within = gpd.sjoin(geo_df, country, how='inner', predicate='within')

# %%
points_outside = geo_df[~geo_df.index.isin(points_within.index)]

# %%
print("Points inside the country:\n")
points_within
# Out:
# Points inside the country:
#      Busines Model                                     Category  \
# 3043           OEM  Apparatus & Machinery for Chemical Industry
# 3044           OEM                                Piping System
# 3045           OEM                     Industrial Turnkey Plant
# 3046           OEM                  Pollution Control Equipment
# 3047           OEM      Pumps, Fans, Compressors & Vacuum Pumps
# ...            ...                                          ...
# 3875           OEM                         Industrial Machinery
# 3876           OEM                         Industrial Machinery
# 3877           OEM                         Industrial Machinery
# 3878           OEM                         Industrial Machinery
# 3879           OEM                         Industrial Machinery
#
#                               Subcategory  \
# 3043  Mechanical seal auxiliary equipment
# 3044  Mechanical seal auxiliary equipment
# 3045  Mechanical seal auxiliary equipment
# 3046  Mechanical seal auxiliary equipment
# 3047  Mechanical seal auxiliary equipment
# ...                                   ...
# 3875                 Industrial Machinery
# 3876                 Industrial Machinery
# 3877                 Industrial Machinery
# 3878                 Industrial Machinery
# 3879                 Industrial Machinery
#
#                                            Company Name  \
# 3043  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3044  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3045  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3046  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# 3047  Eagle Industry Co., Ltd. - Hiroshima Branch Sh...
# ...                                                 ...
# 3875               Seika Corp. - Tokuyama Branch Office
# 3876              Seika Corp. - Yamaguchi Branch Office
# 3877                Seika Corp. - Fukuoka Branch Office
# 3878             Seika Corp. - Kitakyushu Branch Office
# 3879                   Seika Corp. - Oita Branch Office
#
#                                                 Address  Latitude  Longitude  \
# 3043         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# 3044         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# 3045         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# 3046         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# 3047         746-0024 2-20-3 Koizumi, Shunan, Yamaguchi   34.0421   131.8069
# ...                                                 ...       ...        ...
# 3875  745-0036 1-3 Honmachi, Shunan City, Yamaguchi ...   34.0527   131.8036
# 3876  Ube Industries Building, 8-1 Aioicho, Ube City...   33.9548   131.2447
# 3877  810-0004 Fukuoka City Chuo Ward Watanabedori 2...   33.5828   130.4052
# 3878  802-0001 KMM Building 2-14-1 Asano, Kokurakita...   33.8887   130.8835
# 3879  9th floor, Nissei Oita Ekimae Building, 1-1-18...   33.2347   131.6061
#
#            State Country        Contact No.  ... continent region_un  \
# 3043   Yamaguchi   Japan  (+81) 8-3463-7648  ...      Asia      Asia
# 3044   Yamaguchi   Japan  (+81) 8-3463-7648  ...      Asia      Asia
# 3045   Yamaguchi   Japan  (+81) 8-3463-7648  ...      Asia      Asia
# 3046   Yamaguchi   Japan  (+81) 8-3463-7648  ...      Asia      Asia
# 3047   Yamaguchi   Japan  (+81) 8-3463-7648  ...      Asia      Asia
# ...          ...     ...                ...  ...       ...       ...
# 3875   Yamaguchi   Japan  (+81) 8-3421-4407  ...      Asia      Asia
# 3876  Yamaguchi    Japan  (+81) 8-3622-0191  ...      Asia      Asia
# 3877    Fukuoka    Japan  (+81) 9-2731-0471  ...      Asia      Asia
# 3878    Fukuoka    Japan  (+81) 9-3541-1127  ...      Asia      Asia
# 3879       Oita    Japan  (+81) 9-7534-1798  ...      Asia      Asia
#
#          subregion            region_wb  name_len long_len  abbrev_len  tiny  \
# 3043  Eastern Asia  East Asia & Pacific         5        5           5   -99
# 3044  Eastern Asia  East Asia & Pacific         5        5           5   -99
# 3045  Eastern Asia  East Asia & Pacific         5        5           5   -99
# 3046  Eastern Asia  East Asia & Pacific         5        5           5   -99
# 3047  Eastern Asia  East Asia & Pacific         5        5           5   -99
# ...            ...                  ...       ...      ...         ...   ...
# 3875  Eastern Asia  East Asia & Pacific         5        5           5   -99
# 3876  Eastern Asia  East Asia & Pacific         5        5           5   -99
# 3877  Eastern Asia  East Asia & Pacific         5        5           5   -99
# 3878  Eastern Asia  East Asia & Pacific         5        5           5   -99
# 3879  Eastern Asia  East Asia & Pacific         5        5           5   -99
#
#       homepart     featureclass
# 3043         1  Admin-0 country
# 3044         1  Admin-0 country
# 3045         1  Admin-0 country
# 3046         1  Admin-0 country
# 3047         1  Admin-0 country
# ...        ...              ...
# 3875         1  Admin-0 country
# 3876         1  Admin-0 country
# 3877         1  Admin-0 country
# 3878         1  Admin-0 country
# 3879         1  Admin-0 country
#
# [805 rows x 80 columns]

# %%
print("Coordinates outside the country:")
points_outside
# Out:
# Coordinates outside the country:
#      Busines Model                                           Category  \
# 3042           OEM                                 Electric Machinery
# 3647           OEM              Fishing, Animal & Husbandry Machinery
# 3765           OEM                           Industrial Turnkey Plant
# 3766           OEM                           Industrial Turnkey Plant
# 3767           OEM                           Industrial Turnkey Plant
# 3789           OEM                        Material Handling Machinery
# 3807           OEM                        Material Handling Machinery
# 3808           OEM                    Automatic Machinery & Equipment
# 3809           OEM                                 Electric Machinery
# 3822           OEM  Precision Machinery, Inspecting & Testing Equi...
# 3833      End-user                                             Energy
# 3838      End-user                                             Energy
# 3839      End-user                                             Energy
# 3840      End-user                                             Energy
# 3855      End-user                                             Energy
# 3856      End-user                                             Energy
# 3857      End-user                                             Energy
# 3861           OEM                               Industrial Machinery
# 3866           OEM                               Industrial Machinery
# 3867           OEM                               Industrial Machinery
# 3868           OEM                               Industrial Machinery
#
#                      Subcategory  \
# 3042         Calibration Systems
# 3647             Marine Division
# 3765         Production of tanks
# 3766  Large industrial equipment
# 3767       Welding and machining
# 3789         Vibration Equipment
# 3807         Vibration Equipment
# 3808                  FA Systems
# 3809           Power Electronics
# 3822         Precision machining
# 3833                      Energy
# 3838                      Energy
# 3839                      Energy
# 3840                      Energy
# 3855                      Energy
# 3856                      Energy
# 3857                      Energy
# 3861        Industrial Machinery
# 3866        Industrial Machinery
# 3867        Industrial Machinery
# 3868        Industrial Machinery
#
#                                            Company Name  \
# 3042  Eagle Industry Co., Ltd. - Marine Division Kur...
# 3647        Nichimo Co.,Ltd. - Shimonoseki Sales Office
# 3765    Tsukishima Holdings Co., Ltd. - Muroran Factory
# 3766    Tsukishima Holdings Co., Ltd. - Muroran Factory
# 3767    Tsukishima Holdings Co., Ltd. - Muroran Factory
# 3789    Sinfonia Technology Co., Ltd. - Hokuriku Office
# 3807  Sinfonia Technology Co., Ltd. - Shimonoseki Of...
# 3808  Sinfonia Technology Co., Ltd. - Shimonoseki Of...
# 3809  Sinfonia Technology Co., Ltd. - Shimonoseki Of...
# 3822       Sinfonia Technology Co., Ltd. - Toba Factory
# 3833                Seika Corp. - Muroran Branch Office
# 3838                 Seika Corp. - Mihama Branch Office
# 3839                     Seika Corp. - Oi Branch Office
# 3840               Seika Corp. - Takahama Branch Office
# 3855  Seika Corp. - Atomic Power Company Tsuruga Office
# 3856                      Seika Corp. - Kawauchi Office
# 3857                        Seika Corp. - Genkai Office
# 3861                Seika Corp. - Muroran Branch Office
# 3866                 Seika Corp. - Mihama Branch Office
# 3867                     Seika Corp. - Oi Branch Office
# 3868               Seika Corp. - Takahama Branch Office
#
#                                                 Address  Latitude  Longitude  \
# 3042  737-0027 No. 8 1 Showa-cho, Kure City, Hiroshi...   34.2506   132.5651
# 3647  750-0025 3-9-7 Takezakicho, Shimonoseki City, ...   33.9537   130.9213
# 3765    051-0006　35-2 Chazu-cho, Muroran City, Hokkaido   42.3274   140.9892
# 3766    051-0006　35-2 Chazu-cho, Muroran City, Hokkaido   42.3274   140.9892
# 3767    051-0006　35-2 Chazu-cho, Muroran City, Hokkaido   42.3274   140.9892
# 3789  930-0004 Kitanihon Sakurabashi Building, 1-18 ...   36.9077   137.1961
# 3807         752-0953 14-1 Chofu Port Town, Shimonoseki   33.9692   131.0341
# 3808         752-0953 14-1 Chofu Port Town, Shimonoseki   33.9692   131.0341
# 3809         752-0953 14-1 Chofu Port Town, Shimonoseki   33.9692   131.0341
# 3822    517-0011 1-19-1 Toba, Toba City, Mie Prefecture   34.4850   136.8279
# 3833  050-0074 1-23-18 Nakajimacho, Muroran, Hokkaid...   42.3545   141.0178
# 3838  5-3 Kawasakayama, 66 Nyu, Mihama-cho, Mikata-g...   35.7034   135.9716
# 3839  1-1 Yoshimi, Oshima, Oi-cho, Oi-gun, Fukui Pre...   35.5418   135.6554
# 3840  1 Tanoura, Takahama-cho, Oi-gun, Fukui Prefect...   35.5215   135.5043
# 3855  1 Myojin-cho, Tsuruga City, Fukui Prefecture, ...   35.7500   136.0213
# 3856  1765-5 Katahirayama, Kumizakicho, Satsumasenda...   31.8299   130.1901
# 3857  4112-1 Asako, Imamura, Genkai-cho, Higashimats...   33.5169   129.8334
# 3861  050-0074 1-23-18 Nakajimacho, Muroran, Hokkaid...   42.3545   141.0178
# 3866  5-3 Kawasakayama, 66 Nyu, Mihama-cho, Mikata-g...   35.7034   135.9716
# 3867  1-1 Yoshimi, Oshima, Oi-cho, Oi-gun, Fukui Pre...   35.5418   135.6554
# 3868  1 Tanoura, Takahama-cho, Oi-gun, Fukui Prefect...   35.5215   135.5043
#
#            State Country        Contact No.            Fax No.  \
# 3042   Hiroshima   Japan  (+81) 8-2325-7121  (+81) 8-2325-7120
# 3647   Yamaguchi   Japan  (+81) 8-3222-3471  (+81) 8-3232-7216
# 3765    Hokkaido   Japan  (+81) 1-4357-1100  (+81) 1-4357-1102
# 3766    Hokkaido   Japan  (+81) 1-4357-1100  (+81) 1-4357-1102
# 3767    Hokkaido   Japan  (+81) 1-4357-1100  (+81) 1-4357-1102
# 3789      Toyama   Japan  (+81) 7-6432-4551  (+81) 7-6442-2461
# 3807   Yamaguchi   Japan  (+81) 8-3246-4555                  -
# 3808   Yamaguchi   Japan  (+81) 8-3246-4555                  -
# 3809   Yamaguchi   Japan  (+81) 8-3246-4555                  -
# 3822         Mie   Japan  (+81) 5-9925-3231  (+81) 5-9925-5162
# 3833    Hokkaido   Japan  (+81) 1-4344-4047  (+81) 1-4343-6253
# 3838      Fukui    Japan  (+81) 7-7037-3104  (+81) 7-7039-0061
# 3839      Fukui    Japan  (+81) 7-7037-3074  (+81) 7-7077-0201
# 3840      Fukui    Japan  (+81) 7-7037-3037  (+81) 7-7076-1801
# 3855      Fukui    Japan  (+81) 7-7037-3036  (+81) 7-7026-1125
# 3856  Kagoshima    Japan                  -                  -
# 3857       Saga    Japan  (+81) 9-5551-3677  (+81) 9-5551-3678
# 3861    Hokkaido   Japan  (+81) 1-4344-4047  (+81) 1-4343-6253
# 3866      Fukui    Japan  (+81) 7-7037-3104  (+81) 7-7039-0061
# 3867      Fukui    Japan  (+81) 7-7037-3074  (+81) 7-7077-0201
# 3868      Fukui    Japan  (+81) 7-7037-3037  (+81) 7-7076-1801
#
#                                     Website Email   Annual Sale  Employees  \
# 3042                    www.ekkeagle.com/jp     -  1117001501.9       6280
# 3647                     www.nichimo.co.jp/     -   848229574.2       1043
# 3765                       www.tsk-g.co.jp/     -  824652887.25       3517
# 3766                       www.tsk-g.co.jp/     -  824652887.25       3517
# 3767                       www.tsk-g.co.jp/     -  824652887.25       3517
# 3789  www.sinfo-t.jp/company/business-base/     -  681586018.65       3683
# 3807  www.sinfo-t.jp/company/business-base/     -  681586018.65       3683
# 3808  www.sinfo-t.jp/company/business-base/     -  681586018.65       3683
# 3809  www.sinfo-t.jp/company/business-base/     -  681586018.65       3683
# 3822  www.sinfo-t.jp/company/business-base/     -  681586018.65       3683
# 3833                         www.seika.com/     -  576204668.25       1040
# 3838                         www.seika.com/     -  576204668.25       1040
# 3839                         www.seika.com/     -  576204668.25       1040
# 3840                         www.seika.com/     -  576204668.25       1040
# 3855                         www.seika.com/     -  576204668.25       1040
# 3856                         www.seika.com/     -  576204668.25       1040
# 3857                         www.seika.com/     -  576204668.25       1040
# 3861                         www.seika.com/     -  576204668.25       1040
# 3866                         www.seika.com/     -  576204668.25       1040
# 3867                         www.seika.com/     -  576204668.25       1040
# 3868                         www.seika.com/     -  576204668.25       1040
#
#                       geometry
# 3042  POINT (132.5651 34.2506)
# 3647  POINT (130.9213 33.9537)
# 3765  POINT (140.9892 42.3274)
# 3766  POINT (140.9892 42.3274)
# 3767  POINT (140.9892 42.3274)
# 3789  POINT (137.1961 36.9077)
# 3807  POINT (131.0341 33.9692)
# 3808  POINT (131.0341 33.9692)
# 3809  POINT (131.0341 33.9692)
# 3822   POINT (136.8279 34.485)
# 3833  POINT (141.0178 42.3545)
# 3838  POINT (135.9716 35.7034)
# 3839  POINT (135.6554 35.5418)
# 3840  POINT (135.5043 35.5215)
# 3855    POINT (136.0213 35.75)
# 3856  POINT (130.1901 31.8299)
# 3857  POINT (129.8334 33.5169)
# 3861  POINT (141.0178 42.3545)
# 3866  POINT (135.9716 35.7034)
# 3867  POINT (135.6554 35.5418)
# 3868  POINT (135.5043 35.5215)

# %%
points_within.shape[0]
# Out:
# 805

# %%
points_outside.shape[0]
# Out:
# 21

# %%
C_df.shape[0]
# Out:
# 826

# %% [markdown]
# <h4>Visualization</h4>

# %%
fig, ax = plt.subplots(figsize=(12, 12))
country.plot(ax=ax, color='lightgrey', edgecolor='grey')
points_within.plot(ax=ax, color='#67c8fc', markersize=30, label='Inside')
geo_df[~geo_df.index.isin(points_within.index)].plot(ax=ax, color='#fc8a67', markersize=60, label='Outside')

plt.title("Coordinates in Country Borders")
plt.legend()
plt.show()

# %% [markdown]
# <h4>Inspect Rows with Outside Coordinates</h4>

# %%
points_outside[['Company Name', 'Latitude', 'Longitude']].drop_duplicates()
# Out:
#                                            Company Name  Latitude  Longitude
# 3042  Eagle Industry Co., Ltd. - Marine Division Kur...   34.2506   132.5651
# 3647        Nichimo Co.,Ltd. - Shimonoseki Sales Office   33.9537   130.9213
# 3765    Tsukishima Holdings Co., Ltd. - Muroran Factory   42.3274   140.9892
# 3789    Sinfonia Technology Co., Ltd. - Hokuriku Office   36.9077   137.1961
# 3807  Sinfonia Technology Co., Ltd. - Shimonoseki Of...   33.9692   131.0341
# 3822       Sinfonia Technology Co., Ltd. - Toba Factory   34.4850   136.8279
# 3833                Seika Corp. - Muroran Branch Office   42.3545   141.0178
# 3838                 Seika Corp. - Mihama Branch Office   35.7034   135.9716
# 3839                     Seika Corp. - Oi Branch Office   35.5418   135.6554
# 3840               Seika Corp. - Takahama Branch Office   35.5215   135.5043
# 3855  Seika Corp. - Atomic Power Company Tsuruga Office   35.7500   136.0213
# 3856                      Seika Corp. - Kawauchi Office   31.8299   130.1901
# 3857                        Seika Corp. - Genkai Office   33.5169   129.8334

# %%
country_projected = country.to_crs("EPSG:3857")
centroid = country_projected.geometry.centroid.to_crs("EPSG:4326")
center_lat, center_lon = centroid.y.mean(), centroid.x.mean()

# %%
m = folium.Map(location=[center_lat, center_lon], zoom_start=5)

folium.GeoJson(country).add_to(m)

for idx, row in points_outside.iterrows():
    color = 'lightblue' if idx in points_within.index else 'lightred'
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Company Name'],
        icon=folium.Icon(color=color)
    ).add_to(m)

m.save('map.html')

# %%
webbrowser.open('map.html',new = 2)
# Out:
# True

# %% [markdown]
# <h4>Correct Latitude and Longitude</h4>

# %% [markdown]
# <b>Before correcting the coordinates, check the `map.html` file to confirm. Sometimes, the Python calculations are not accurate.</b>

# %%
# Sinfonia Technology Co., Ltd. - Shimonoseki Office
C_df.loc[C_df['Company Name'] == 'Sinfonia Technology Co., Ltd. - Shimonoseki Office', 
    ['Latitude', 'Longitude']] = [34.0067, 130.9972]

# Sinfonia Technology Co., Ltd. - Hokuriku Office
C_df.loc[C_df['Company Name'] == 'Sinfonia Technology Co., Ltd. - Hokuriku Office', 
    ['Latitude', 'Longitude']] = [36.6977, 137.2162]

# %% [markdown]
# <h4>Finalize Coordinates</h4>

# %%
C_df_copy = C_df

# %%
geo_df = gpd.GeoDataFrame(C_df_copy, geometry = gpd.points_from_xy(
    C_df_copy['Longitude'], C_df_copy['Latitude']), crs="EPSG:4326")

# %%
points_within = gpd.sjoin(geo_df, country, how='inner', predicate='within')
points_outside = geo_df[~geo_df.index.isin(points_within.index)]

# %%
country_projected = country.to_crs("EPSG:3857")
centroid = country_projected.geometry.centroid.to_crs("EPSG:4326")
center_lat, center_lon = centroid.y.mean(), centroid.x.mean()

# %%
m = folium.Map(location=[center_lat, center_lon], zoom_start=5)

folium.GeoJson(country).add_to(m)

for idx, row in points_outside.iterrows():
    color = 'lightblue' if idx in points_within.index else 'lightred'
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=row['Company Name'],
        icon=folium.Icon(color=color)
    ).add_to(m)

m.save('map_corrected.html')

# %%
webbrowser.open('map_corrected.html',new = 2)
# Out:
# True

# %% [markdown]
# <h3>📝 Correct Incorrect Entries</h3>

# %% [markdown]
# <h4>Resolve Busines Model</h4>

# %%
C_df['Busines Model'].unique()
# Out:
# array(['OEM', 'End-user'], dtype=object)

# %% [markdown]
# <h4>Resolve Category</h4>

# %%
Categories = np.sort(C_df['Category'].unique())
Categories
# Out:
# array(['Agricultural Machinery',
#        'Apparatus & Machinery for Chemical Industry',
#        'Automatic Machinery & Equipment', 'Beverage Machinery', 'Boiler',
#        'Casting', 'Chemical', 'Construction Machinery', 'Dryers',
#        'Electric Machinery', 'Electronic', 'Energy',
#        'Equipment for Smelting Plant & Rolling Mills',
#        'Fishing, Animal & Husbandry Machinery', 'Food', 'Food Machinery',
#        'Forging & Stamping', 'Freezing & Air Conditioning Equipment',
#        'Gaming Machines', 'Grinders, Crushers & Screen Machines',
#        'Hardware, Metal Products & Other Products of Materials',
#        'Heat Treatment Equipment',
#        'Heating, Ventilation, & Air Conditioning (HVAC)',
#        'Hydraulic Presses, Pneumatic & Hydraulic Machinery',
#        'Industrial Machinery', 'Industrial Turnkey Plant',
#        'Industrial Turnkey Plant ', 'Lifting Equipment',
#        'Machinery Equipment for Services',
#        'Machinery for Non-metallic Mineral Products',
#        'Machinery for Processing Plastics',
#        'Machinery for Rubber Industry', 'Marine Machinery & Equipment',
#        'Material Handling Machinery', 'Medical Machines & Equipment',
#        'Metal Cutting Tools', 'Metal Forming Machinery',
#        'Mining Machinery', 'NC Machines', 'Office Machinery',
#        'Packaging Machinery', 'Pharmaceutical Machinery', 'Piping System',
#        'Planning, Consulting & Construction of Complete Industrial Plant',
#        'Pollution Control Equipment', 'Precision Machinery',
#        'Precision Machinery, Inspecting & Testing Equipment',
#        'Printing & Binding Machinery',
#        'Productronics Machinery & Equipment',
#        'Pumps, Fans, Compressors & Vacuum Pumps',
#        'Refrigerating Equipment',
#        'Repair, Maintenance & Installation of Machinery', 'Semiconductor',
#        'Semiconductor Machinery', 'Special Machine Tools',
#        'Subcontract Services', 'Textile Machinery',
#        'Tools, Cutters, Moulds, & Dies', 'Transportation Equipment',
#        'Water / Wastewater Machinery', 'Welding & Cutting Machinery'],
#       dtype=object)

# %%
C_df.loc[C_df['Category'] == 'Chemical', 'Category'] = 'Apparatus & Machinery for Chemical Industry'
C_df['Category'] = C_df['Category'].str.replace('Industrial Turnkey Plant ','Industrial Turnkey Plant')
C_df.loc[C_df['Category'] == 'Semiconductor', 'Category'] = 'Semiconductor Machinery'
C_df.loc[C_df['Category'] == 'Electronic', 'Category'] = 'Electric Machinery'
C_df.loc[C_df['Category'] == 'Energy', 'Category'] = 'Electric Machinery'
C_df.loc[C_df['Category'] == 'Food', 'Category'] = 'Food Machinery'
C_df['Category'] = C_df['Category'].str.replace('\n','')
C_df.loc[C_df['Category'] == 'Precision Machinery', 'Category'] = 'Precision Machinery, Inspecting & Testing Equipment'

# %%
Categories = np.sort(C_df['Category'].unique())

for i in Categories:
    print(i)
# Out:
# Agricultural Machinery
# Apparatus & Machinery for Chemical Industry
# Automatic Machinery & Equipment
# Beverage Machinery
# Boiler
# Casting
# Construction Machinery
# Dryers
# Electric Machinery
# Equipment for Smelting Plant & Rolling Mills
# Fishing, Animal & Husbandry Machinery
# Food Machinery
# Forging & Stamping
# Freezing & Air Conditioning Equipment
# Gaming Machines
# Grinders, Crushers & Screen Machines
# Hardware, Metal Products & Other Products of Materials
# Heat Treatment Equipment
# Heating, Ventilation, & Air Conditioning (HVAC)
# Hydraulic Presses, Pneumatic & Hydraulic Machinery
# Industrial Machinery
# Industrial Turnkey Plant
# Lifting Equipment
# Machinery Equipment for Services
# Machinery for Non-metallic Mineral Products
# Machinery for Processing Plastics
# Machinery for Rubber Industry
# Marine Machinery & Equipment
# Material Handling Machinery
# Medical Machines & Equipment
# Metal Cutting Tools
# Metal Forming Machinery
# Mining Machinery
# NC Machines
# Office Machinery
# Packaging Machinery
# Pharmaceutical Machinery
# Piping System
# Planning, Consulting & Construction of Complete Industrial Plant
# Pollution Control Equipment
# Precision Machinery, Inspecting & Testing Equipment
# Printing & Binding Machinery
# Productronics Machinery & Equipment
# Pumps, Fans, Compressors & Vacuum Pumps
# Refrigerating Equipment
# Repair, Maintenance & Installation of Machinery
# Semiconductor Machinery
# Special Machine Tools
# Subcontract Services
# Textile Machinery
# Tools, Cutters, Moulds, & Dies
# Transportation Equipment
# Water / Wastewater Machinery
# Welding & Cutting Machinery

# %% [markdown]
# <h4>Resolve Subcategory</h4>

# %%
C_df['Subcategory'] = C_df['Subcategory'].str.title()

# %%
C_df['Subcategory'] = C_df['Subcategory'].str.replace(', And',' And')

# %%
Subcategories = np.sort(C_df['Subcategory'].unique())

for i in Subcategories:
    print(i)
# Out:
# 3D Printing, Cnc Machining
# A Combination Of Design, Engineering, Prototyping And Small-Scale Production
# Advanced Fishing Gear
# Aerospace Systems
# Agricultural Equipment Systems
# Agricultural Machinery
# Air-Cooled Heat Pump Chiller
# Arcade Machines
# Aseptic Filling & Decontamination Systems
# Auto Splicing Unit
# Automatic Machinery & Equipment
# Bending Roll
# Bending Rolls
# Beverage Machinery
# Boiler
# Bottling System
# Calibration Systems
# Casting
# Casting Equipment
# Clean Transport System (Semiconductor)
# Cleaning Equipment
# Cleaning/Environmental Equipment System
# Cnc Portal Drilling Machine
# Cnc Vertical Lathe
# Co2 Laser Cutting Machine
# Construction Machinery
# Control Devices And Drive Systems
# Crushing, Grinding, Classifying And Granulating Equipment
# Decoration/Surface Treatment
# Development Of Medical Devices
# Diamond Core Drill Machines
# Digital Modeling, Cg, Optical Analysis
# Distribution Division
# Dredge Pump
# Dredge Pumps
# Drying And Baking Equipment
# Drying/Dehydration Units
# Electric Discharge Machine
# Electric Machinery
# Electrical And Automation Equipment
# Electrical Distribution And Fa Systems For Construction
# Electronic
# Electronic Control Equipment
# Electronic Control Systems For Regional Industries
# Elevator
# Energy
# Energy And Infrastructure
# Engineering Services For The Healthcare Sector
# Engineering Support For Water
# Environmental Plant Engineering
# Environmental Plant Equipment Sales And Consulting
# Extrusion Molding Machines
# Fa Systems
# Factory Automation And Power Equipment
# Food Division
# Food Equipment
# Food Machinery
# Food Processing Systems
# Food-Related Packaging Systems
# Forging Press
# Freezing & Air Conditioning Equipment
# Generator
# Group Management
# Heating, Ventilation, & Air Conditioning (Hvac)
# Hydraulic Press
# Industrial Automation
# Industrial Automation Systems
# Industrial Machinery
# Industrial Network Systems
# Inserters
# Large Industrial Equipment
# Laser Processing Machine
# Life Support Systems
# Local Sales Support For Environmental Systems
# Machine Tools
# Machinery Division
# Machinery For Non-Metallic Mineral Products
# Machinery-Related Testing
# Machining Systems
# Marine Division
# Marine Equipment
# Materials Division
# Mechanical Design
# Mechanical Seal Auxiliary Equipment
# Medical Equipment
# Medical Equipment Systems
# Metal Cutting Tools
# Metal Forming Machinery
# Mining Machinery
# Mixing, Kneading And Reaction Equipment
# Molding Machine
# Municipal Sewage
# Packaging Innovations
# Packaging Machinery
# Packaging Solutions
# Parts Feeder
# Pharmaceutical
# Pharmaceutical Equipment Systems
# Pharmaceutical Machinery
# Pharmaceutical Manufacturing Systems
# Piping System
# Plant Production Control
# Plant Sales Headquarters
# Polycon Frp Pipes
# Power Electonics
# Power Electronics
# Power Sprayer
# Precision Machining
# Printers
# Printing Systems
# Processed Food Technology
# Product Design, Proof Of Concept (Poc)
# Production Of Tanks
# Productronics Equipment
# Productronics Machinery & Equipment
# Proof Of Concept (Poc)
# Pumps
# Refrigerating Equipment
# Refrigeration And Cooling Equipment
# Regenerative Medicine Systems
# Regional Control Systems
# Regional Support For Water
# Repair, Maintenance & Installation Of Machinery
# Resin Processing, Block Molding
# Sales And Project Support For Treatment Plants
# Sales Of Beverage
# Sales Of Integrated Production Systems Including Aseptic Filling
# Seafood
# Semiconductor
# Semiconductor
# Semiconductor Production Equipment
# Semiconductor Systems For Energy, Metals And Automotive
# Semiconductor/Battery Manufacturing Systems
# Semiconductors
# Sensors, Servo Motors, Automation Parts
# Sheet Metal Processing
# Simple Mold, Injection Molding, Small-Scale Production
# Smt Pick And Place Machines
# Soap & Detergents
# Solder Print Inspection
# Solvent Recovery, Deodorization And Exhaust Gas Treatment Equipment
# Special Boiler
# Spm
# Steam Turbines
# Synthetic Resin And Materials
# Test Equipment
# Textile Machinery
# Tractors
# Transportation Equipment
# Ultra-Precision Processing Machines
# Vacuum Casting, Microwave Molding
# Vibration Equipment
# Vibrator
# Waste Treatment Support
# Wastewaster Treatment Solution
# Wastewater Treatment Systems
# Water / Wastewater Machinery
# Water Treatment Consulting
# Water Treatment Systems
# Welding & Cutting Machinery
# Welding And Machining
# West Japan Environmental Engineering Projects

# %%
C_df.loc[C_df['Subcategory'] == 'Bending Roll', 'Subcategory'] = 'Bending Rolls'
C_df.loc[C_df['Subcategory'] == 'Dredge Pump', 'Subcategory'] = 'Dredge Pumps'
C_df.loc[C_df['Subcategory'] == 'Power Electonics', 'Subcategory'] = 'Power Electronics'
C_df.loc[C_df['Subcategory'] == 'Product Design, Proof Of Concept (Poc)', 'Subcategory'] = 'Product Design'
C_df.loc[C_df['Subcategory'] == 'Semiconductor ', 'Subcategory'] = 'Semiconductor'
C_df.loc[C_df['Subcategory'] == 'Semiconductors', 'Subcategory'] = 'Semiconductor'
C_df.loc[C_df['Subcategory'] == 'Wastewaster Treatment Solution ', 'Subcategory'] = 'Wastewater Treatment Systems'

# %%
C_df['Subcategory'] = C_df['Subcategory'].str.replace('Cnc','CNC')
C_df['Subcategory'] = C_df['Subcategory'].str.replace('Co2','CO2')
C_df['Subcategory'] = C_df['Subcategory'].str.replace('Hvac','HVAC')
C_df['Subcategory'] = C_df['Subcategory'].str.replace('Frp','FRP')
C_df['Subcategory'] = C_df['Subcategory'].str.replace('Smt','SMT')
C_df['Subcategory'] = C_df['Subcategory'].str.replace('Fa ','FA ')
C_df['Subcategory'] = C_df['Subcategory'].str.replace('Spm','SPM')
C_df['Subcategory'] = C_df['Subcategory'].str.replace('Cg','CG')
C_df['Subcategory'] = C_df['Subcategory'].str.replace('(Poc)','(POC)')

# %%
Subcategories = np.sort(C_df['Subcategory'].unique())

for i in Subcategories:
    print(i)
# Out:
# 3D Printing, CNC Machining
# A Combination Of Design, Engineering, Prototyping And Small-Scale Production
# Advanced Fishing Gear
# Aerospace Systems
# Agricultural Equipment Systems
# Agricultural Machinery
# Air-Cooled Heat Pump Chiller
# Arcade Machines
# Aseptic Filling & Decontamination Systems
# Auto Splicing Unit
# Automatic Machinery & Equipment
# Bending Rolls
# Beverage Machinery
# Boiler
# Bottling System
# CNC Portal Drilling Machine
# CNC Vertical Lathe
# CO2 Laser Cutting Machine
# Calibration Systems
# Casting
# Casting Equipment
# Clean Transport System (Semiconductor)
# Cleaning Equipment
# Cleaning/Environmental Equipment System
# Construction Machinery
# Control Devices And Drive Systems
# Crushing, Grinding, Classifying And Granulating Equipment
# Decoration/Surface Treatment
# Development Of Medical Devices
# Diamond Core Drill Machines
# Digital Modeling, CG, Optical Analysis
# Distribution Division
# Dredge Pumps
# Drying And Baking Equipment
# Drying/Dehydration Units
# Electric Discharge Machine
# Electric Machinery
# Electrical And Automation Equipment
# Electrical Distribution And FA Systems For Construction
# Electronic
# Electronic Control Equipment
# Electronic Control Systems For Regional Industries
# Elevator
# Energy
# Energy And Infrastructure
# Engineering Services For The Healthcare Sector
# Engineering Support For Water
# Environmental Plant Engineering
# Environmental Plant Equipment Sales And Consulting
# Extrusion Molding Machines
# FA Systems
# Factory Automation And Power Equipment
# Food Division
# Food Equipment
# Food Machinery
# Food Processing Systems
# Food-Related Packaging Systems
# Forging Press
# Freezing & Air Conditioning Equipment
# Generator
# Group Management
# Heating, Ventilation, & Air Conditioning (HVAC)
# Hydraulic Press
# Industrial Automation
# Industrial Automation Systems
# Industrial Machinery
# Industrial Network Systems
# Inserters
# Large Industrial Equipment
# Laser Processing Machine
# Life Support Systems
# Local Sales Support For Environmental Systems
# Machine Tools
# Machinery Division
# Machinery For Non-Metallic Mineral Products
# Machinery-Related Testing
# Machining Systems
# Marine Division
# Marine Equipment
# Materials Division
# Mechanical Design
# Mechanical Seal Auxiliary Equipment
# Medical Equipment
# Medical Equipment Systems
# Metal Cutting Tools
# Metal Forming Machinery
# Mining Machinery
# Mixing, Kneading And Reaction Equipment
# Molding Machine
# Municipal Sewage
# Packaging Innovations
# Packaging Machinery
# Packaging Solutions
# Parts Feeder
# Pharmaceutical
# Pharmaceutical Equipment Systems
# Pharmaceutical Machinery
# Pharmaceutical Manufacturing Systems
# Piping System
# Plant Production Control
# Plant Sales Headquarters
# Polycon FRP Pipes
# Power Electronics
# Power Sprayer
# Precision Machining
# Printers
# Printing Systems
# Processed Food Technology
# Product Design
# Production Of Tanks
# Productronics Equipment
# Productronics Machinery & Equipment
# Proof Of Concept (POC)
# Pumps
# Refrigerating Equipment
# Refrigeration And Cooling Equipment
# Regenerative Medicine Systems
# Regional Control Systems
# Regional Support For Water
# Repair, Maintenance & Installation Of Machinery
# Resin Processing, Block Molding
# SMT Pick And Place Machines
# SPM
# Sales And Project Support For Treatment Plants
# Sales Of Beverage
# Sales Of Integrated Production Systems Including Aseptic Filling
# Seafood
# Semiconductor
# Semiconductor Production Equipment
# Semiconductor Systems For Energy, Metals And Automotive
# Semiconductor/Battery Manufacturing Systems
# Sensors, Servo Motors, Automation Parts
# Sheet Metal Processing
# Simple Mold, Injection Molding, Small-Scale Production
# Soap & Detergents
# Solder Print Inspection
# Solvent Recovery, Deodorization And Exhaust Gas Treatment Equipment
# Special Boiler
# Steam Turbines
# Synthetic Resin And Materials
# Test Equipment
# Textile Machinery
# Tractors
# Transportation Equipment
# Ultra-Precision Processing Machines
# Vacuum Casting, Microwave Molding
# Vibration Equipment
# Vibrator
# Waste Treatment Support
# Wastewater Treatment Systems
# Water / Wastewater Machinery
# Water Treatment Consulting
# Water Treatment Systems
# Welding & Cutting Machinery
# Welding And Machining
# West Japan Environmental Engineering Projects

# %% [markdown]
# <h4>Resolve State</h4>

# %%
C_df['State'].unique()
# Out:
# array(['Hiroshima', 'Yamaguchi', 'Okayama', 'Fukuoka', 'Tokyo',
#        'Shizuoka ', 'Miyagi ', 'Aichi ', 'Osaka ', 'Fukuoka ', 'Gunma ',
#        'Hiroshima ', 'Kanagawa ', 'Ehime', 'Osaka', 'Saitama',
#        'Yamanashi', 'Aichi', 'Miyagi', 'Hokkaido', 'Okinawa', 'Ibaraki',
#        'Shiga', 'Chiba', 'Fukushima', 'Aomori', 'Iwate', 'Nagasaki',
#        'Kanagawa', 'Nagano', 'Kumamoto', 'Ishikawa ', 'Hyogo', 'Kochi',
#        'Nagoya', 'Niigata', 'Saitama ', 'Toyama', 'Shizuoka', 'Mie',
#        'Wakayama', 'Kagawa', 'Tokushima', 'Chiba ', 'Fukui ', 'Fukui',
#        'Kagawa ', 'Ehime ', 'Okayama ', 'Yamaguchi ', 'Oita ',
#        'Miyazaki ', 'Nagasaki ', 'Kagoshima ', 'Saga ', 'Shimane ',
#        'Tokyo '], dtype=object)

# %%
C_df['State'] = C_df['State'].str.replace(' ', '', regex=True)

# %%
C_df['State'].unique()
# Out:
# array(['Hiroshima', 'Yamaguchi', 'Okayama', 'Fukuoka', 'Tokyo',
#        'Shizuoka', 'Miyagi', 'Aichi', 'Osaka', 'Gunma', 'Kanagawa',
#        'Ehime', 'Saitama', 'Yamanashi', 'Hokkaido', 'Okinawa', 'Ibaraki',
#        'Shiga', 'Chiba', 'Fukushima', 'Aomori', 'Iwate', 'Nagasaki',
#        'Nagano', 'Kumamoto', 'Ishikawa', 'Hyogo', 'Kochi', 'Nagoya',
#        'Niigata', 'Toyama', 'Mie', 'Wakayama', 'Kagawa', 'Tokushima',
#        'Fukui', 'Oita', 'Miyazaki', 'Kagoshima', 'Saga', 'Shimane'],
#       dtype=object)

# %% [markdown]
# <h4>Resolve Country</h4>

# %%
C_df['Country'].unique()
# Out:
# array(['Japan'], dtype=object)

# %% [markdown]
# <h3>📈 Detect and Treat Outliers</h3>

# %%
plt.style.use('fivethirtyeight')

# %% [markdown]
# <h4>Check Latitude</h4>

# %%
plt.scatter(C_df['Latitude'], C_df['Latitude'], color='#fc67a5')
plt.show()

# %% [markdown]
# <h4>Check Longitude</h4>

# %%
plt.scatter(C_df['Longitude'], C_df['Longitude'], color='#fc8a67')
plt.show()

# %% [markdown]
# <h4>Check Annual Sales</h4>

# %%
plt.scatter(C_df['Annual Sale'], C_df['Annual Sale'], color='#67fcc8')
plt.show()

# %% [markdown]
# <h4>Check Employees</h4>

# %%
plt.scatter(C_df['Employees'], C_df['Employees'], color='#67c8fc')
plt.show()

# %% [markdown]
# So far, there are <b>no outliers</b> in the dataset.

# %% [markdown]
# <h2>🔎 Finalize Dataset</h2>

# %% [markdown]
# <h3>Check Data Types</h3>

# %%
C_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 826 entries, 3042 to 3879
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Busines Model  826 non-null    object
#  1   Category       826 non-null    object
#  2   Subcategory    826 non-null    object
#  3   Company Name   826 non-null    object
#  4   Address        826 non-null    object
#  5   Latitude       826 non-null    float64
#  6   Longitude      826 non-null    float64
#  7   State          826 non-null    object
#  8   Country        826 non-null    object
#  9   Contact No.    826 non-null    object
#  10  Fax No.        826 non-null    object
#  11  Website        826 non-null    object
#  12  Email          826 non-null    object
#  13  Annual Sale    826 non-null    Float64
#  14  Employees      826 non-null    Int64
# dtypes: Float64(1), Int64(1), float64(2), object(11)
# memory usage: 104.9+ KB

# %% [markdown]
# <h3>Check For Null Values</h3>

# %%
C_df.isnull().any()
# Out:
# Busines Model    False
# Category         False
# Subcategory      False
# Company Name     False
# Address          False
# Latitude         False
# Longitude        False
# State            False
# Country          False
# Contact No.      False
# Fax No.          False
# Website          False
# Email            False
# Annual Sale      False
# Employees        False
# dtype: bool

# %% [markdown]
# <h3>Summarize Dataset</h3>

# %%
C_df.describe()
# Out:
#          Latitude   Longitude       Annual Sale    Employees
# count  826.000000  826.000000             826.0        826.0
# mean    35.349206  136.330997  855046711.958257   2847.59322
# std      2.280396    3.473326  227106503.822827  1424.344804
# min     26.215900  127.677900       14082273.45         69.0
# 25%     34.561400  133.774600      771975490.95       2121.0
# 50%     35.113700  136.630100      836072741.25       2911.0
# 75%     35.670600  139.740400     1067872480.25       3507.0
# max     43.107200  141.958600      1685492700.0       7104.0

# %% [markdown]
# <h3>Check Random Samples</h3>

# %%
C_df.sample(5)
# Out:
#      Busines Model                           Category  \
# 3552           OEM                      Piping System
# 3233           OEM  Machinery for Processing Plastics
# 3086           OEM        Pollution Control Equipment
# 3265           OEM             Agricultural Machinery
# 3685           OEM             Agricultural Machinery
#
#                               Subcategory  \
# 3552                    Polycon FRP Pipes
# 3233           Extrusion Molding Machines
# 3086  Mechanical Seal Auxiliary Equipment
# 3265                             Tractors
# 3685               Agricultural Machinery
#
#                                       Company Name  \
# 3552               Kurimoto, Ltd. - Sendai Factory
# 3233  Shibaura Machine Co., Ltd. - Gotemba Factory
# 3086      Eagle Industry Co., Ltd. - Kyushu Branch
# 3265                                      Yamabiko
# 3685                                   Taiho Kogyo
#
#                                                 Address  Latitude  Longitude  \
# 3552  981-3513 Miyagi Prefecture Kurokawa-gun Ogo-ch...   38.4368   141.0413
# 3233         412-0038 1-120 Komakado, Gotemba, Shizuoka   35.3086   138.9345
# 3086  812‐0013 2nd floor, Hakata Ekimae 2nd Building...   33.5903   130.4207
# 3265         1-7-2 Suehirocho, Ome City, Tokyo 198-0025   35.7802   139.3090
# 3685  3-65 Midorigaoka, Toyota City, Aichi Prefectur...   35.0640   137.1450
#
#          State Country        Contact No.            Fax No.  \
# 3552    Miyagi   Japan  (+81) 2-2347-6201                  -
# 3233  Shizuoka   Japan  (+81) 5-5087-3555  (+81) 5-5087-3742
# 3086   Fukuoka   Japan  (+81) 9-2710-7139  (+81) 9-2710-7158
# 3265     Tokyo   Japan  (+81) 4-2832-1005                  -
# 3685     Aichi   Japan  (+81) 5-6528-2225  (+81) 5-6528-2227
#
#                                Website Email    Annual Sale  Employees
# 3552               www.kurimoto.co.jp/     -   836072741.25       2121
# 3233       www.shibaura-machine.co.jp/     -  1074278578.35       3507
# 3086               www.ekkeagle.com/jp     -   1117001501.9       6280
# 3265  www.yamabiko-corp.co.jp/kioritz/     -    259229538.0        476
# 3685               www.taihonet.co.jp/     -    743910535.8       7104

# %% [markdown]
# <h2>📥 Download Dataset</h2>

# %%
C_df.to_csv('datasets\output\Dataset_C_cleaned.csv', index=False)

# %% [markdown]
# <h2>💌 Credits ✉️</h2>

# %% [markdown]
# This project is done by <b>ERMITANO, Kate Justine</b> as a part of the internship tasks under the instructions of <b>Miss Fherlyn Charl Yet</b>.
